# %% [markdown]
# # 범주별 연속형 수치데이터 분포 비교
#
# * boxplot
# * violinplot

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris = pd.read_csv('./data/iris.csv')
tips = pd.read_csv('./data/tips.csv')

# %% [markdown]
# ## 박스 그래프
# 하나의 연속형 변수에 대해서 분포 형태, 퍼짐정도, 이상치 여부 등을 시각화하고, 하나의 그룹 혹은 여러개의 그룹 간 비교하는데 유용하다.

# %%
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

box = axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
ax = sns.boxplot(y=tips["total_bill"])

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = sns.boxplot(x="day", y="total_bill", order=['Thur','Fri','Sat','Sun'], data=tips)

# %% [markdown]
# ## 바이올린 그래프
# 상자그래프에서 데이터 분포를 커널 밀도 추정을 통해 그린 그래프가 바이올린 그래프이다.

# %%
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
# 남/여 색상 구별하기
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True) 
plt.show()

# %% [markdown]
# ### sina plot
# box plot이나 violin plot 에 swarmplot을 겹쳐서 그리면 데이터의 분포를 더 자세히 표현할 수 있다.
#
# * swarmplot : 데이터 포인트가 서로 중복되지 않도록 산점도를 시각화한다.

# %%
ax = sns.boxplot(x="total_bill", y="day", data=tips, whis=np.inf)
ax = sns.swarmplot(x="total_bill", y="day", data=tips, color=".2")

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
ax = sns.swarmplot(x="day", y="total_bill", data=tips,
                   color="white", edgecolor="gray")

# %%
ax = sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
ax = sns.stripplot(x="tip", y="day", data=tips, color=".3")

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips,
                    inner=None, color=".8")
ax = sns.stripplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# # 박스 그래프, 바이올린 그래프 실습
#
# 1. 타이타닉 데이터 셋을 읽어 들인다.
# ```
# titanic = pd.read_csv('./data/titanic.csv')
# titanic.info()
# ```
# 2. 성(Sex)별 나이(Age)의 분포를 박스 그래프로 시각화하여 비교해 보시오.
# 3. 선실등급(Pclass)별 나이의 분포를 바이올린 그래프로 나타내는데 성(Sex)별에 따라 좌우를 나누어 시각화 하시오.
