# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # 막대그래프 실습
# 1. 타이타닉 데이터 셋을 읽어 들인다.
# ```
# titanic = pd.read_csv('./data/titanic.csv')
# titanic.info()
# ```
#
# 2. 선실 등급(Pclass)별 생존율을 막대그래프로 그려 비교하시오.
#
# 3. 선실 등급, 성별에 따라서 생존율을 병렬 막대 그래프로 비교하시오.

# %%
titanic = pd.read_csv('./data/titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.barplot(x='Pclass', y='Survived', data=titanic, ci=None)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='Pclass', y='Survived', hue='Sex', data=titanic, ci=None)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.pointplot(x="Pclass", y="Survived", hue="Sex",
            linestyles=["-", "--"],
            data=titanic)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# # 히스토그램 밀도그래프 실습
#
# 1. 타이타닉 데이터 셋을 읽어 들인다.
# ```
# iris = pd.read_csv('./data/iris.csv')
# iris.info()
# ```
# 2. "petal_length"의 분포를 히스토그램으로 나타내시오.
# 3. "species"별로 "petal_length"의 분포를 히스토그램으로 나타내시오.
# 4. 'petal_length'와 'sepal_length'의 분포를 kde plot으로 시각화 하시오.
# 5. 'petal_length'와 'sepal_length'의 kde plot을 종(species)별로 비교하여 시각화 하시오.

# %%
iris = pd.read_csv('./data/iris.csv')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.hist(iris.petal_length)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(data=iris, x='petal_length', hue='species', alpha=0.5, bins=20)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %%
sns.kdeplot(data=iris, x='petal_length', y='sepal_length', fill=True)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.kdeplot(data=iris, x='petal_length', y='sepal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>

# %% [markdown]
# # 박스 그래프, 바이올린 그래프 실습
#
# 1. 타이타닉 데이터 셋을 읽어 들인다.
# ```
# titanic = pd.read_csv('./data/titanic.csv')
# titanic.info()
# ```
# 2. 성(Sex)별 나이(Age)의 분포를 박스 그래프로 시각화하여 비교해 보시오.
# 3. 선실등급(Pclass)별 나이의 분포를 바이올린 그래프로 나타내는데 성(Sex)별에 따라 좌우를 나누어 시각화 하시오.

# %%
import pandas as pd
titanic = pd.read_csv('./data/titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.boxplot(data=titanic, x = 'Sex', y='Age')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x='Pclass', y='Age', hue='Sex', data=titanic, split=True)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 산점도 실습
#
# 1. './data/stock_px.csv' 에는 2003년 1월에서 2011년 10월 사이의 미국 주식 주가 데이터를 포함하고 있다.
# ```
# stock_px = pd.read_csv('./data/stock_px.csv', parse_dates=True, index_col=0)
# stock_px.info()
# ```
# * date : 날짜
# * AAPL : 애플 주가
# * MSFT : 마이크로소프트 주가
# * XOM : 엑슨모빌 주가
# * SPX : S&P 500 지수
#
# 2. SPX와 MSFT의 산점도를 시각화 하시오.
# 3. pandas의 hexbin을 사용하여 SPX와 MSFT의 산점도를 시각화 하시오.

# %%
stock_px = pd.read_csv('./data/stock_px.csv', parse_dates=True, index_col=0)
stock_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
plt.plot('MSFT','SPX', 
         data=stock_px,
        marker='o', 
        linestyle='none', 
        alpha=0.5)

# %%
fig, ax = plt.subplots()
ax = stock_px.plot.hexbin(x='MSFT', y='SPX', gridsize=15, ax = ax)

# %% [markdown]
# # strip_swarm 실습하기
#
# 1. iris 데이터 셋을 읽어들인다.
# ```
# iris = pd.read_csv('./data/iris.csv')
# iris.info()
# ```
#
# 2. 종(Species)별 petal_length의 분포를 strip chart로 시각화 하시오.
# 3. 종(Species)별 petal_length의 분포를 swarm plot으로 시각화 하시오.
# 4. 3번의 내용을 바이올린 플롯과 strip chart를 겹쳐 그려 시각화 하시오.

# %%
iris = pd.read_csv('./data/iris.csv')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.stripplot(x='species', y='petal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
plt.figure(figsize=(8,5))
sns.swarmplot(x='species', y='petal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(x='species', y='petal_length', data=iris)
sns.stripplot(x='species', y='petal_length', color='grey', alpha=0.5, data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# # 비율 시각화 실습 - 막대, 파이
#
# 1. 타이타닉 데이터 셋을 읽어들인다.
# ```
# titanic = pd.read_csv('./data/titanic.csv')
# titanic.info()
# ```
# 2. 남여 성별 생존율을 막대 그래프로 시각화 하시오.
# 3. 남여 성별 생존율을 파이 차트로 시각화 하시오.

# %%
titanic = pd.read_csv('./data/titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
new_df = titanic.groupby('Survived')['Sex'].value_counts(normalize=True)
new_df = new_df.mul(100).rename('Percent').reset_index()
new_df
# Out:
#    Survived     Sex    Percent
# 0         0    male  85.245902
# 1         0  female  14.754098
# 2         1  female  68.128655
# 3         1    male  31.871345

# %%
survived = new_df[new_df['Survived']==1]

# %%
sns.barplot(data=survived, x='Sex', y='Percent')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Percent'>

# %%
ratio = survived['Percent'].values
labels = survived['Sex'].values

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=90)
plt.show()

# %% [markdown]
# # 모자이크 실습
#
# 1. 타이타닉 데이터 셋을 읽어들인다.
# ```
# titanic = pd.read_csv('./data/titanic.csv')
# titanic.info()
# ```
#
# 2. 선실 등급별 생존율을 모자이크 플롯으로 시각화 하시오.

# %%
titanic = pd.read_csv('./data/titanic.csv')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
labelizer = lambda k : 'dead\n'+k[1] if k[0]=='0' else 'survived\n'+k[1]

mosaic(titanic, ['Survived', 'Pclass'],labelizer = labelizer)

plt.ylabel("PClass")
# Out:
# Text(0, 0.5, 'PClass')

# %% [markdown]
# # 산점도 행렬 실습
#
# 1. iris 데이터셋을 읽어 들이시오.
# ```
# iris = pd.read_csv('./data/iris.csv')
# iris.info()
# ```
# 2. sepal_length sepal_width petal_length petal_width의 상관관계 쌍을 산점도 행렬을 그려서 나타내시오.

# %%
iris = pd.read_csv('./data/iris.csv')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Iris Pair Plot, Hue로 꽃의 종을 시각화
sns.pairplot(iris, hue="species", markers=["o", "s", "D"],
             palette="husl")
plt.show()

# %% [markdown]
# # 히트맵 실습
#
# 1. './data/stock_px.csv' 에는 2003년 1월에서 2011년 10월 사이의 미국 주식 주가 데이터를 포함하고 있다.
# ```
# df = pd.read_csv('./data/stock_px.csv', parse_dates=True, index_col=0)
# df.info()
# ```
# * date : 날짜
# * AAPL : 애플 주가
# * MSFT : 마이크로소프트 주가
# * XOM : 엑슨모빌 주가
# * SPX : S&P 500 지수
#
# 2. 변수의 상관계수를 히트맵으로 시각화 하시오.

# %%
stock_px = pd.read_csv('./data/stock_px.csv', parse_dates=True, index_col=0)
stock_px.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %%
corr = stock_px.corr()

corr.style.background_gradient(cmap='Blues', axis=None)
# Out:
# <style  type="text/css" >
# #T_290d1_row0_col0,#T_290d1_row1_col1,#T_290d1_row2_col2,#T_290d1_row3_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_290d1_row0_col1,#T_290d1_row1_col0{
#             background-color:  #9ac8e0;
#             color:  #000000;
#         }#T_290d1_row0_col2,#T_290d1_row2_col0{
#             background-color:  #4191c6;
#             color:  #000000;
#         }#T_290d1_row0_col3,#T_290d1_row3_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_290d1_row1_col2,#T_290d1_row2_col1{
#             background-color:  #74b3d8;
#             color:  #000000;
#         }#T_290d1_row1_col3,#T_290d1_row3_col1{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_290d1_row2_col3,#T_290d1_row3_col2{
#             background-color:  #9dcae1;
#             color:  #000000;
# ...

# %%
ax = sns.heatmap(corr, annot=True, annot_kws=dict(color='k'), cmap='Blues')
plt.show()

# %% [markdown]
# # 시계열 데이터 처리하기 실습
#
# './data/stock_px.csv' 에는 2003년 1월에서 2011년 10월 사이의 미국 주식 주가 데이터를 포함하고 있다.
#
# * date : 날짜
# * AAPL : 애플 주가
# * MSFT : 마이크로소프트 주가
# * XOM : 엑슨모빌 주가
# * SPX : S&P 500 지수

# %%
import pandas as pd

df = pd.read_csv('./data/stock_px.csv', parse_dates=True, index_col=0)
df.head()
# Out:
#             AAPL   MSFT    XOM     SPX
# Date
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59
# 2003-01-06  7.45  21.52  29.96  929.01
# 2003-01-07  7.43  21.93  28.95  922.93
# 2003-01-08  7.28  21.31  28.83  909.93

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2214 entries, 2003-01-02 to 2011-10-14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    2214 non-null   float64
#  1   MSFT    2214 non-null   float64
#  2   XOM     2214 non-null   float64
#  3   SPX     2214 non-null   float64
# dtypes: float64(4)
# memory usage: 86.5 KB

# %% [markdown]
# ### 문제 1.
# 'AAPL' 애플 주식을 선그래프로 시각화 하시오.( hint. plot 메소드 사용)

# %%
df['AAPL'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 문제2.
# 'AAPL' 애플 주식의 2011년 데이터만 선그래프로 시각화하시오.

# %%
df['AAPL'].loc['2011'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 문제3.
# 'AAPL' 애플 주식의 연도별('A') 평균을 막대그래프로 시각화하시오. (hint. resample 메소드의 사용)

# %%
df['AAPL'].resample('A').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### 문제 4.
# 'AAPL' 애플 주식의 120일 이동평균선을 선그래프로 시각화 하시오. (hint. rolling 사용)

# %%
df['AAPL'].plot(label='AAPL')
df['AAPL'].rolling(window=120).mean().plot(label='120 moving average')
# Out:
# <AxesSubplot:xlabel='Date'>
